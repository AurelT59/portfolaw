# %%
import os

directory = '/home/sagemaker-user/shared/directive_extraction/directives_translated'

for file in os.listdir(directory):
    full_path = os.path.join(directory, file)
    if os.path.isfile(full_path):
        with open(full_path, 'r', encoding='utf-8') as f:
            content = f.read()
        print(f"{file}: {len(content)} caractères")
    else:
        print(f"{file}: ce n'est pas un fichier")
# Out:
# .ipynb_checkpoints: ce n'est pas un fichier
# 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL_en.json: 107766 caractères
# 2.H.R.1 - One Big Beautiful Bill Act_en.json: 938820 caractères
# 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL_en.json: 654115 caractères
# 5.中华人民共和国能源法__中国政府网_en.json: 88898 caractères
# 6.人工知能関連技術の研究開発及び活用の推進に関する法律_en.json: 20908 caractères
# 3.H.R.5376 - Inflation Reduction Act of 2022_en.json: 779679 caractères

# %%
from bs4 import BeautifulSoup

with open("directive.html", "r", encoding="utf-8") as f:
    soup = BeautifulSoup(f, "html.parser")
    full_text = soup.get_text(separator="\n")

# %%
import os
import boto3
from bs4 import BeautifulSoup
import json

# --- Configurations ---
directory = '/home/sagemaker-user/shared/directive_extraction/directives'
translated_dir = '/home/sagemaker-user/shared/directive_extraction/directives_translated'
os.makedirs(translated_dir, exist_ok=True)

# --- Client Amazon Translate ---
translate = boto3.client('translate', region_name='us-west-2')

# --- Extraire le texte ---
def extract_text_from_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        content = f.read()
    soup = BeautifulSoup(content, 'html.parser')
    return soup.get_text(separator="\n")

# --- Découper le texte par taille en bytes ---
def split_text_by_bytes(text, max_bytes=9000):
    paragraphs = text.split("\n")
    chunks = []
    current_chunk = ""
    for para in paragraphs:
        if len((current_chunk + para + "\n").encode('utf-8')) <= max_bytes:
            current_chunk += para + "\n"
        else:
            if current_chunk:
                chunks.append(current_chunk.strip())
            # Si un paragraphe seul dépasse max_bytes, on le découpe en morceaux
            while len(para.encode('utf-8')) > max_bytes:
                slice_bytes = para.encode('utf-8')[:max_bytes]
                slice_text = slice_bytes.decode('utf-8', errors='ignore')
                chunks.append(slice_text.strip())
                para = para[len(slice_text):]
            current_chunk = para + "\n"
    if current_chunk:
        chunks.append(current_chunk.strip())
    return chunks

# --- Traduire en plusieurs parties ---
def translate_text_in_chunks(text, source_lang='auto', target_lang='en'):
    chunks = split_text_by_bytes(text)
    translated_chunks = []
    for i, chunk in enumerate(chunks):
        response = translate.translate_text(
            Text=chunk,
            SourceLanguageCode=source_lang,
            TargetLanguageCode=target_lang
        )
        translated_chunks.append(response['TranslatedText'])
    return translated_chunks

# --- Traitement de tous les fichiers ---
for file in os.listdir(directory):
    full_path = os.path.join(directory, file)
    if os.path.isfile(full_path):
        print(f"Traitement de {file}...")
        text = extract_text_from_file(full_path)
        translated_chunks = translate_text_in_chunks(text)

        # Sauvegarde en JSON avec plusieurs parties
        output_file = os.path.join(translated_dir, f"{os.path.splitext(file)[0]}_en.json")
        with open(output_file, 'w', encoding='utf-8') as f_out:
            json.dump({'original_file': file, 'translated_chunks': translated_chunks}, f_out, ensure_ascii=False, indent=2)

        print(f"{file} → traduit et sauvegardé dans {output_file}")
    else:
        print(f"{file} n'est pas un fichier")
# Out:
# .ipynb_checkpoints n'est pas un fichier
# Traitement de 3.H.R.5376 - Inflation Reduction Act of 2022.xml...
# 3.H.R.5376 - Inflation Reduction Act of 2022.xml → traduit et sauvegardé dans /home/sagemaker-user/shared/directive_extraction/directives_translated/3.H.R.5376 - Inflation Reduction Act of 2022_en.json
# Traitement de 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL.html...
# 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL.html → traduit et sauvegardé dans /home/sagemaker-user/shared/directive_extraction/directives_translated/4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL_en.json
# Traitement de 5.中华人民共和国能源法__中国政府网.html...
# 5.中华人民共和国能源法__中国政府网.html → traduit et sauvegardé dans /home/sagemaker-user/shared/directive_extraction/directives_translated/5.中华人民共和国能源法__中国政府网_en.json
# Traitement de 6.人工知能関連技術の研究開発及び活用の推進に関する法律.html...
# 6.人工知能関連技術の研究開発及び活用の推進に関する法律.html → traduit et sauvegardé dans /home/sagemaker-user/shared/directive_extraction/directives_translated/6.人工知能関連技術の研究開発及び活用の推進に関する法律_en.json
# Traitement de 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL.html...
# 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL.html → traduit et sauvegardé dans /home/sagemaker-user/shared/directive_extraction/directives_translated/1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL_en.json
# Traitement de 2.H.R.1 - One Big Beautiful Bill Act.xml...
# 2.H.R.1 - One Big Beautiful Bill Act.xml → traduit et sauvegardé dans /home/sagemaker-user/shared/directive_extraction/directives_translated/2.H.R.1 - One Big Beautiful Bill Act_en.json

# %%
law_analysis_prompt = """
You are an expert legal and economic analyst. Your task is to carefully analyze the following law, directive, or regulation and summarize all its important measures. For each measure, extract and explain its impact on the following dimensions:

1. **Economic Impact**: Potential costs, fines, subsidies, incentives, compliance requirements, effect on revenues, margins, or valuations.  
2. **Geographic Scope**: Countries, regions, extraterritorial effects.  
3. **Political / Regulatory Impact**: Changes in governance, authority responsibilities, enforcement mechanisms.  
4. **Sector / Industry Impact**: Which industries, value chain segments, or business types are affected.  

Instructions:  
- For each measure, quote the **exact original text** from the law that justifies your analysis.  
- Use clear, structured language and categorize each measure under the dimensions above.  
- If a dimension is not applicable, write "N/A".  
- Provide a concise but thorough summary for decision-makers and analysts.  
- I want at least 5 measures of the text.

Output format (JSON example):

{
  "summry": {
    "overall_summary": "",
    "main_themes": [],
    "key_impacts": "",
    "recommendations": ""
  },
  "measures": [
    {
      "original_text": "Text quoted from the law with article number",
      "economic_impact": "...",
      "geography": "...",
      "political_impact": "...",
      "sector_industry_impact": "..."
    },
    {
      "original_text": "...",
      "economic_impact": "...",
      "geography": "...",
      "political_impact": "...",
      "sector_industry_impact": "..."
    }
  ]
}


Analyze the following law text and return your structured summary exactly in this JSON format and nothing more:
"""

# %%
import json
import boto3
from botocore.config import Config

# --- Config Bedrock ---
config = Config(region_name="us-west-2", connect_timeout=30, read_timeout=300)
bedrock = boto3.client("bedrock-runtime", config=config)

# --- Charger le JSON ---
json_file = "/home/sagemaker-user/shared/directive_extraction/directives_translated/2.H.R.1 - One Big Beautiful Bill Act_en.json"
with open(json_file, "r", encoding="utf-8") as f:
    data = json.load(f)
# --- Construire le prompt à partir des chunks ---
def build_prompt_from_chunks(chunks, law_analysis_prompt):
    for i, chunk in enumerate(chunks, start=1):
        law_analysis_prompt += f"\nChunk {i}:\n{chunk}\n"

    law_analysis_prompt += "\nReturn a single structured JSON object following the schema exactly."
    return law_analysis_prompt

prompt = build_prompt_from_chunks(data["translated_chunks"], law_analysis_prompt)
#prompt = law_analysis_prompt + "\n\n" + full_text
# --- Appel Bedrock ---
body = {
        "anthropic_version": "bedrock-2023-05-31",
        "max_tokens": 10000,
        "temperature": 0.1,
        "messages": [{"role": "user", "content": [{"type": "text", "text": prompt}]}],
    }

response = bedrock.invoke_model(
    modelId="anthropic.claude-3-sonnet-20240229-v1:0",
    body=json.dumps(body),
    contentType="application/json"
)
# --- Récupérer le texte renvoyé par le modèle ---
response_body = json.loads(response["body"].read())
reviewed_translation = response_body["content"][0]["text"]


try:
    final_json = json.loads(reviewed_translation)
except json.JSONDecodeError:
    print("Le modèle n'a pas renvoyé un JSON valide. Voici le texte brut :")
    print(reviewed_translation)
    final_json = None

# --- Afficher le JSON final ---
if final_json:
    print(json.dumps(final_json, indent=2, ensure_ascii=False))
# Out:
# {
#   "summary": {
#     "overall_summary": "This law establishes the basic principles, policies, and institutional framework for promoting research, development, and utilization of artificial intelligence (AI) technology in Japan. It aims to contribute to improving people's lives and the healthy development of the national economy by comprehensively and systematically promoting measures related to AI technology.",
#     "main_themes": [
#       "Basic principles and philosophy for AI technology research, development, and utilization",
#       "Responsibilities of the government, local public bodies, research institutions, businesses, and citizens",
#       "Promotion of research, development, education, international cooperation, and infrastructure sharing",
#       "Establishment of the Artificial Intelligence Strategy Headquarters and the Artificial Intelligence Basic Plan"
#     ],
#     "key_impacts": "The law sets the foundation for a coordinated national strategy to advance AI technology, involving various stakeholders and promoting international cooperation. It aims to enhance Japan's competitiveness in AI while ensuring transparency and proper implementation.",
#     "recommendations": "Stakeholders should align their efforts with the basic principles and cooperate with the government's policies and measures outlined in the law. The government should periodically review the law's implementation and make necessary adjustments based on changing conditions."
#   },
#   "measures": [
#     {
#       "original_text": "Article 3: Research and development and utilization of artificial intelligence-related technology shall be carried out based on the basic principles stipulated in this section...",
#       "economic_impact": "Promoting AI technology can lead to significant efficiency gains and creation of new industries, improving economic competitiveness.",
#       "geography": "N/A",
#       "political_impact": "Establishes basic principles and philosophy for AI technology research, development, and utilization, guiding government policies.",
#       "sector_industry_impact": "Potentially impacts various sectors and industries through AI technology adoption and creation of new AI-enabled products and services."
#     },
#     {
#       "original_text": "Article 4: The country has the basic principles set forth in the preceding article (hereinafter referred to as the \"basic philosophy\") In accordance with this, it is responsible for comprehensively and systematically formulating and implementing measures related to the promotion of research and development and utilization of artificial intelligence-related technology.",
#       "economic_impact": "N/A",
#       "geography": "National level",
#       "political_impact": "Assigns responsibility to the national government for formulating and implementing measures related to AI technology promotion.",
#       "sector_industry_impact": "N/A"
#     },
#     {
#       "original_text": "Article 6: Universities, research and development corporations, and other institutions that conduct research and development of artificial intelligence-related technology as stipulated in the Act on Revitalization of Science, Technology, and Innovation Creation (Heisei 20 Law No. 63) (hereinafter referred to as \"research and development institutions\") In accordance with the basic principles, it will actively endeavor to research and develop artificial intelligence-related technology, disseminate its results, and develop human resources with specialized and wide-ranging knowledge, and endeavor to cooperate with policies implemented by the country based on the provisions of Article 4 and measures implemented by local public bodies based on the provisions of the preceding article.",
#       "economic_impact": "Research and development institutions are expected to contribute to AI technology advancement, potentially leading to economic benefits through innovation and skilled workforce development.",
#       "geography": "N/A",
#       "political_impact": "Assigns responsibilities to research and development institutions to cooperate with national and local government policies on AI technology promotion.",
#       "sector_industry_impact": "Impacts research and development institutions, including universities and corporations, involved in AI technology research and development."
#     },
#     {
#       "original_text": "Article 18: In accordance with the basic principles, the government has a basic plan (hereinafter referred to as the \"Artificial Intelligence Basic Plan\") relating to the promotion of research and development and utilization of artificial intelligence-related technology based on the basic measures stipulated in the previous chapter. It shall be determined.",
#       "economic_impact": "The Artificial Intelligence Basic Plan can guide investments, policies, and initiatives related to AI technology, potentially impacting various economic sectors.",
#       "geography": "National level",
#       "political_impact": "Establishes the Artificial Intelligence Basic Plan as the government's guiding document for promoting AI technology research, development, and utilization.",
#       "sector_industry_impact": "The Basic Plan can influence various sectors and industries through AI technology adoption and development."
#     },
#     {
#       "original_text": "Article 19: In order to comprehensively and systematically promote measures related to the promotion of research and development and utilization of artificial intelligence-related technologies, the Artificial Intelligence Strategy Headquarters (hereinafter referred to as the \"headquarters\") is organized by the Cabinet Put it down.",
#       "economic_impact": "N/A",
#       "geography": "National level",
#       "political_impact": "Establishes the Artificial Intelligence Strategy Headquarters as the central body responsible for coordinating and promoting AI technology measures.",
#       "sector_industry_impact": "N/A"
#     }
#   ]
# }

# %%
import json

json_file = "/home/sagemaker-user/shared/directive_extraction/directives_translated/2.H.R.1 - One Big Beautiful Bill Act_en.json"
with open(json_file, "r", encoding="utf-8") as f:
    data = json.load(f)

chunks = data["translated_chunks"]

print(f"Nombre total de chunks : {len(chunks)}")
lengths = [len(c) for c in chunks]
print(f"Taille moyenne des chunks : {sum(lengths)//len(lengths)} caractères")
print(f"Taille max : {max(lengths)}, Taille min : {min(lengths)}")
print(f"Somme totale : {sum(lengths)} caractères")
# Out:
# Nombre total de chunks : 105
# Taille moyenne des chunks : 8638 caractères
# Taille max : 8974, Taille min : 1979
# Somme totale : 907043 caractères

# %%
import os
import json
import boto3
from botocore.config import Config
import time

# --- Config Bedrock ---
config = Config(region_name="us-west-2", connect_timeout=30, read_timeout=300)
bedrock = boto3.client("bedrock-runtime", config=config)

# --- Paramètres ---
name = "4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL_en.json"
json_file = os.path.join("/home/sagemaker-user/shared/directive_extraction/directives_translated", name)
max_chars_per_batch = 200000  # Taille cible par lot
output_file = os.path.join("/home/sagemaker-user/shared/directive_extraction/summary", name)

# --- Charger le JSON ---
with open(json_file, "r", encoding="utf-8") as f:
    data = json.load(f)

chunks = data["translated_chunks"]

print(f"\n📦 Nombre de chunks d'origine : {len(chunks)}")
lengths = [len(c) for c in chunks]
print(f"Taille moyenne : {sum(lengths)//len(lengths)} | Max : {max(lengths)} | Min : {min(lengths)}")
print(f"Somme totale du texte : {sum(lengths)} caractères")

# --- Regrouper les chunks en lots de ~200k caractères ---
def group_chunks(chunks, max_chars):
    grouped = []
    current_group = []
    current_len = 0
    for chunk in chunks:
        if current_len + len(chunk) > max_chars and current_group:
            grouped.append("\n".join(current_group))
            current_group = [chunk]
            current_len = len(chunk)
        else:
            current_group.append(chunk)
            current_len += len(chunk)
    if current_group:
        grouped.append("\n".join(current_group))
    return grouped

batches = group_chunks(chunks, max_chars_per_batch)

print(f"🧩 Nombre de lots après regroupement : {len(batches)}")

# --- Construire le prompt ---
def build_prompt(batch_text, law_analysis_prompt):
    return f"{law_analysis_prompt}\n\n{batch_text}\n\nReturn a single JSON following the schema exactly."

# --- Appel Bedrock ---
def call_bedrock(prompt):
    body = {
        "anthropic_version": "bedrock-2023-05-31",
        "max_tokens": 8000,
        "temperature": 0.1,
        "messages": [{"role": "user", "content": [{"type": "text", "text": prompt}]}],
    }

    response = bedrock.invoke_model(
        modelId="anthropic.claude-3-sonnet-20240229-v1:0",
        body=json.dumps(body),
        contentType="application/json",
    )

    response_body = json.loads(response["body"].read())
    text = response_body["content"][0]["text"]

    try:
        return json.loads(text)
    except json.JSONDecodeError:
        print("⚠️ Réponse non-JSON valide, texte brut :")
        print(text)
        return None

# --- Traitement des lots ---
all_results = []

for i, batch in enumerate(batches, start=1):
    print(f"\n🔹 Traitement du lot {i}/{len(batches)} (taille : {len(batch)} caractères)...")
    prompt = build_prompt(batch, law_analysis_prompt)
    result = call_bedrock(prompt)
    if result:
        all_results.append(result)
    time.sleep(2)

# --- Fusion finale ---
final_json = {"summary": "", "measures": []}

for res in all_results:
    # Si le résumé est encore vide et qu'on en trouve un → on garde seulement le premier
    if not final_json["summary"] and "summary" in res:
        final_json["summary"] = res["summary"]
    
    # On fusionne toujours les mesures de tous les lots
    if "measures" in res:
        final_json["measures"].extend(res["measures"])

# --- Sauvegarde ---
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(final_json, f, indent=2, ensure_ascii=False)

print(f"\n✅ Analyse terminée. Résultat sauvegardé dans : {output_file}")
# Out:
# 📦 Nombre de chunks d'origine : 73
# Taille moyenne : 8484 | Max : 8936 | Min : 3702
# Somme totale du texte : 619372 caractères
# 🧩 Nombre de lots après regroupement : 4
#
# 🔹 Traitement du lot 1/4 (taille : 198545 caractères)...
#
# 🔹 Traitement du lot 2/4 (taille : 199642 caractères)...
#
# 🔹 Traitement du lot 3/4 (taille : 199796 caractères)...
# ⚠️ Réponse non-JSON valide, texte brut :
# {
#   "summary": {
#     "overall_summary": "The law text provides detailed regulations for artificial intelligence (AI) systems in the European Union. It establishes harmonized rules for the development, marketing, and use of AI systems, with a focus on ensuring safety, fundamental rights protection, and ethical principles.",
#     "main_themes": [
#       "Risk-based approach to regulating AI systems",
#       "Requirements and obligations for providers and users of high-risk AI systems",
#       "Prohibited AI practices",
#       "Governance and enforcement mechanisms",
#       "Support for innovation and SMEs"
#     ],
#     "key_impacts": "The regulation aims to create a harmonized legal framework for AI in the EU, promoting innovation while mitigating risks associated with AI systems. It imposes strict requirements on high-risk AI systems and prohibits certain harmful AI practices.",
#     "recommendations": "Stakeholders, including providers, users, and national authorities, should carefully study the regulation and ensure compliance with the relevant requirements and obligations. Particular attention should be paid to the provisions related to high-risk AI systems and prohibited practices."
#   },
#   "measures": [
#     {
#       "original_text": "3. The Commission shall adopt delegated acts in accordance with Article 97 to amend the thresholds listed in paragraphs 1 and 2 of this Article, as well as to supplement benchmarks and indicators in light of evolving technological developments, such as algorithmic improvements or increased hardware efficiency, when necessary, for these thresholds to reflect the state of the art.",
#       "economic_impact": "This provision allows the Commission to update the regulation's thresholds and benchmarks, which could impact the compliance requirements and associated costs for AI system providers and users.",
#       "geography": "N/A",
#       "political_impact": "The ability to amend thresholds and benchmarks through delegated acts gives the Commission flexibility to adapt the regulation to technological developments.",
#       "sector_industry_impact": "This measure could potentially affect various sectors and industries that develop or use AI systems, as the thresholds and benchmarks may change over time."
#     },
#     {
#       "original_text": "1. Where a general-purpose AI model meets the condition referred to in Article 51(1), point (a), the relevant provider shall notify the Commission without delay and in any event within two weeks after that requirement is met or it becomes known that it will be met. That notification shall include the information necessary to demonstrate that the relevant requirement has been met. If the Commission becomes aware of a general-purpose AI model presenting systemic risks of which it has not been notified, it may decide to designate it as a model with systemic risk.",
#       "economic_impact": "Providers of general-purpose AI models with systemic risks must notify the Commission, which may involve administrative costs. Failure to comply could result in fines or other penalties.",
#       "geography": "N/A",
#       "political_impact": "This measure gives the Commission the power to designate general-purpose AI models as presenting systemic risks, even if not notified by the provider.",
#       "sector_industry_impact": "This measure primarily impacts providers of general-purpose AI models, particularly those with potential systemic risks."
#     },
#     {
#       "original_text": "(a) draw up and keep up-to-date the technical documentation of the model, including its training and testing process and the results of its evaluation, which shall contain, at a minimum, the information set out in Annex XI for the purpose of providing it, upon request, to the AI Office and the national competent authorities;",
#       "economic_impact": "Providers of general-purpose AI models must maintain detailed technical documentation, which may involve additional costs and administrative burdens.",
#       "geography": "N/A",
#       "political_impact": "This measure enhances transparency and accountability by requiring providers to document their AI models and make the information available to authorities upon request.",
#       "sector_industry_impact": "This measure primarily impacts providers of general-purpose AI models across various sectors."
#     },
#     {
#       "original_text": "1. Providers of general-purpose AI models with systemic risk shall:
# (a) perform model evaluation in accordance with standardised protocols and tools reflecting the state of the art, including conducting and documenting adversarial testing of the model with a view to identifying and mitigating systemic risks;",
#       "economic_impact": "Providers of general-purpose AI models with systemic risks must conduct model evaluations and adversarial testing, which may involve additional costs and resources.",
#       "geography": "N/A",
#       "political_impact": "This measure aims to mitigate systemic risks associated with certain AI models by requiring rigorous evaluation and testing procedures.",
#       "sector_industry_impact": "This measure primarily impacts providers of general-purpose AI models with systemic risks, which could span various sectors."
#     },
#     {
#       "original_text": "1. The Commission shall develop Union expertise and capabilities in the field of AI through the AI Office.",
#       "economic_impact": "The establishment of the AI Office may involve additional funding and resources from the Commission, which could have economic implications.",
#       "geography": "N/A",
#       "political_impact": "This measure creates a centralized body (the AI Office) within the Commission to develop expertise and capabilities in the field of AI, potentially increasing the Commission's influence and authority in this area.",
#       "sector_industry_impact": "The AI Office's activities and expertise could potentially impact various sectors and industries that develop or use AI systems."
#     }
#   ]
# }
#
# 🔹 Traitement du lot 4/4 (taille : 21458 caractères)...
#
# ✅ Analyse terminée. Résultat sauvegardé dans : /home/sagemaker-user/shared/directive_extraction/summary/4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL_en.json

# %%
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(final_json, f, indent=2, ensure_ascii=False)

print(f"\n✅ Analyse terminée. Résultat sauvegardé dans : {output_file}")

# %%
import json

# --- Spécifie ton chemin de fichier JSON ---
file_path = "/home/sagemaker-user/shared/law_on_companies/summary/1.portfolio_analysis.json"

# --- Charger et afficher le contenu ---
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Affichage lisible
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "summary": {
#     "overall_portfolio_impact": "Moderate to High",
#     "key_risk_sectors": [
#       "Technology",
#       "Consumer Discretionary",
#       "Industrials",
#       "Consumer Staples"
#     ],
#     "key_risk_countries": [
#       "United States",
#       "China",
#       "European Union"
#     ],
#     "recommendations": "Reduce exposure to high-risk sectors like Technology and Consumer Discretionary. Consider geographic diversification away from high regulatory risk regions like the US, China and EU. Replace holdings with high regulatory risk scores with lower risk alternatives in the same sectors."
#   },
#   "portfolio_analysis": [
#     {
#       "symbol": "NVDA",
#       "company_name": "NVIDIA Corporation",
#       "sector": "Information Technology",
#       "country_exposure": "United States, China, Taiwan",
#       "regulatory_risk_score": "High",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "Article 7 paragraph 4 bis requires disclosure of ranking parameters for consumer search results, impacting NVIDIA's AI and data center products. Article 6 bis paragraph 1 requires disclosures around third-party seller information on online marketplaces, potentially affecting NVIDIA's gaming ecosystem.",
#       "justify_dependance_risk": "Significant reliance on suppliers in Taiwan, South Korea and China for components and manufacturing.",
#       "recommended_adjustments": "Reduce exposure to NVDA given high regulatory risk from EU directives impacting core AI/data center and gaming businesses. Consider alternatives like AMD or Intel with lower regulatory risk exposure."
#     },
#     {
#       "symbol": "MSFT",
#       "company_name": "Microsoft Corporation",
#       "sector": "Information Technology",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "High",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "Article 7 paragraph 4 bis on disclosure of search ranking parameters impacts Microsoft's Bing search engine and advertising business. Article 6 bis paragraph 1 on online marketplace disclosures is relevant for Microsoft's gaming/app stores.",
#       "justify_dependance_risk": "Microsoft has a diversified global supply chain and operations.",
#       "recommended_adjustments": "Reduce MSFT exposure due to high regulatory risk from EU directives impacting search, advertising and online marketplace businesses. Alternatives like Oracle or IBM may have lower risk."
#     },
#     {
#       "symbol": "AAPL",
#       "company_name": "Apple Inc.",
#       "sector": "Information Technology",
#       "country_exposure": "United States, China",
#       "regulatory_risk_score": "Moderate",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "Article 6 bis paragraph 1 on online marketplace disclosures is relevant for Apple's App Store. However, Apple's core hardware business faces relatively lower regulatory risk.",
#       "justify_dependance_risk": "Highly dependent on suppliers in China and other Asian countries for manufacturing and components.",
#       "recommended_adjustments": "Maintain AAPL position but monitor for supply chain disruption risks given high dependence on Chinese suppliers. Consider lowering exposure if US-China tensions escalate."
#     },
#     {
#       "symbol": "AMZN",
#       "company_name": "Amazon.com, Inc.",
#       "sector": "Consumer Discretionary",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "High",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "Article 6 bis paragraph 1 on online marketplace disclosures directly impacts Amazon's e-commerce platform. Article 3 paragraph 1 bis extends directive to digital services/content involving consumer data, affecting Amazon's cloud/streaming businesses.",
#       "justify_dependance_risk": "While Amazon has a global supply chain, it is likely optimized for its core e-commerce operations.",
#       "recommended_adjustments": "Reduce AMZN exposure due to very high regulatory risk from multiple EU directive provisions impacting e-commerce, cloud and digital media segments."
#     },
#     {
#       "symbol": "META",
#       "company_name": "Meta Platforms, Inc.",
#       "sector": "Communication Services",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Moderate",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "Article 6 bis paragraph 1 on online marketplace disclosures is somewhat relevant for Meta's app stores and VR/AR ecosystems, but core advertising business faces lower risk.",
#       "justify_dependance_risk": "Meta has a diversified supply chain for its consumer hardware and infrastructure needs.",
#       "recommended_adjustments": "Maintain position in META as regulatory risk is moderate. Monitor for any expansion of EU rules around advertising practices."
#     },
#     {
#       "symbol": "AVGO",
#       "company_name": "Broadcom Inc.",
#       "sector": "Information Technology",
#       "country_exposure": "United States, Singapore, China",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As a semiconductor and infrastructure software company, Broadcom faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Broadcom likely has some supplier exposure to China and other Asian countries for its semiconductor manufacturing operations.",
#       "recommended_adjustments": "Maintain position in AVGO as regulatory risk is low. Monitor for potential supply chain disruptions due to geopolitical tensions."
#     },
#     {
#       "symbol": "GOOGL",
#       "company_name": "Alphabet Inc.",
#       "sector": "Communication Services",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "High",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "Article 7 paragraph 4 bis on disclosure of search ranking parameters directly impacts Google's core search business. Article 6 bis paragraph 1 on online marketplace disclosures affects Google's app stores and shopping platforms.",
#       "justify_dependance_risk": "Alphabet has a diversified global supply chain and operations.",
#       "recommended_adjustments": "Reduce exposure to GOOGL due to high regulatory risk from EU directives targeting Google's search, advertising and e-commerce businesses. Consider alternatives like Microsoft or Amazon with relatively lower risk."
#     },
#     {
#       "symbol": "GOOG",
#       "company_name": "Alphabet Inc.",
#       "sector": "Communication Services",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "High",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "Same justification as GOOGL - high risk from EU rules around search rankings and online marketplaces.",
#       "justify_dependance_risk": "Same as GOOGL.",
#       "recommended_adjustments": "Same as GOOGL - reduce exposure."
#     },
#     {
#       "symbol": "TSLA",
#       "company_name": "Tesla, Inc.",
#       "sector": "Consumer Discretionary",
#       "country_exposure": "United States, China",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "As an automotive and energy company, Tesla faces relatively low direct risk from the EU consumer directives.",
#       "justify_dependance_risk": "Tesla is highly dependent on suppliers, likely including single-source suppliers in China, for EV components and manufacturing.",
#       "recommended_adjustments": "Maintain position but closely monitor for supply chain disruptions given Tesla's dependence on Chinese suppliers. Consider reducing exposure if US-China tensions escalate."
#     },
#     {
#       "symbol": "JPM",
#       "company_name": "JPMorgan Chase & Co.",
#       "sector": "Financials",
#       "country_exposure": "United States, Worldwide",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "As a financial services company, JPMorgan faces low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "JPMorgan has a diversified global operating footprint and supply chain.",
#       "recommended_adjustments": "Maintain position in JPM as both regulatory and dependence risks are low."
#     },
#     {
#       "symbol": "WMT",
#       "company_name": "Walmart Inc.",
#       "sector": "Consumer Staples",
#       "country_exposure": "United States, Mexico, Canada, China",
#       "regulatory_risk_score": "Moderate",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "Article 23 ter prohibiting misleading claims about product reviews is relevant for Walmart's e-commerce operations. However, overall regulatory risk is moderate for Walmart's diversified retail business.",
#       "justify_dependance_risk": "Significant reliance on suppliers in China and other countries for merchandise and components.",
#       "recommended_adjustments": "Maintain position but monitor for supply chain risks due to high supplier dependence, especially in China. Consider reducing exposure if geopolitical tensions disrupt supply chains."
#     },
#     {
#       "symbol": "ORCL",
#       "company_name": "Oracle Corporation",
#       "sector": "Information Technology",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As an enterprise software and cloud services provider, Oracle faces relatively low direct risk from the EU consumer directives.",
#       "justify_dependance_risk": "Oracle likely has some dependence on Asian suppliers for hardware manufacturing and components.",
#       "recommended_adjustments": "Maintain position in ORCL as regulatory risk is low. Monitor for potential supply chain disruptions."
#     },
#     {
#       "symbol": "V",
#       "company_name": "Visa Inc.",
#       "sector": "Information Technology",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "As a payments technology company, Visa faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Visa has a diversified global footprint and likely diversified supply chain for its services-oriented business model.",
#       "recommended_adjustments": "Maintain position in V as both regulatory and dependence risks are low."
#     },
#     {
#       "symbol": "LLY",
#       "company_name": "Eli Lilly and Company",
#       "sector": "Health Care",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As a pharmaceutical company, Lilly faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Lilly likely has some dependence on international suppliers for raw materials and manufacturing of pharmaceutical products.",
#       "recommended_adjustments": "Maintain position in LLY. Monitor for potential supply chain disruptions but overall risk is relatively low."
#     },
#     {
#       "symbol": "MA",
#       "company_name": "Mastercard Incorporated",
#       "sector": "Information Technology",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "As a payments technology company like Visa, Mastercard faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Mastercard has a diversified global footprint and services-oriented business model with likely low supply chain dependence.",
#       "recommended_adjustments": "Maintain position in MA as both regulatory and dependence risks are low."
#     },
#     {
#       "symbol": "NFLX",
#       "company_name": "Netflix, Inc.",
#       "sector": "Communication Services",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "As a streaming entertainment provider, Netflix faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Netflix's business model as a streaming service provider likely has low supply chain dependence.",
#       "recommended_adjustments": "Maintain position in NFLX as both regulatory and dependence risks are low."
#     },
#     {
#       "symbol": "XOM",
#       "company_name": "Exxon Mobil Corporation",
#       "sector": "Energy",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "As an integrated oil and gas company, ExxonMobil faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "ExxonMobil has significant global operations and likely high dependence on suppliers across its supply chain for exploration, production, refining and distribution activities.",
#       "recommended_adjustments": "Maintain position but monitor for supply chain disruption risks given ExxonMobil's complex global supply chain and operations."
#     },
#     {
#       "symbol": "COST",
#       "company_name": "Costco Wholesale Corporation Walmart Inc.",
#       "sector": "Consumer Staples",
#       "country_exposure": "United States, Canada, Mexico, Other International",
#       "regulatory_risk_score": "Moderate",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "Article 23 ter prohibiting misleading claims about product reviews is relevant for Costco's e-commerce and retail operations. However, overall risk is moderate.",
#       "justify_dependance_risk": "Costco likely has high dependence on suppliers across the globe, including China, for its merchandise sourcing and supply chain.",
#       "recommended_adjustments": "Maintain position but closely monitor supply chain risks, especially related to China sourcing. Consider reducing exposure if geopolitical tensions escalate."
#     },
#     {
#       "symbol": "PLTR",
#       "company_name": "Palantir Technologies Inc.",
#       "sector": "Information Technology",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "As a data analytics software provider, Palantir faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Palantir's software business model likely has low supply chain dependence.",
#       "recommended_adjustments": "Maintain position in PLTR as both regulatory and dependence risks are low."
#     },
#     {
#       "symbol": "JNJ",
#       "company_name": "Johnson & Johnson",
#       "sector": "Health Care",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As a healthcare company focused on pharmaceuticals and medical devices, J&J faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "J&J likely has some dependence on international suppliers for raw materials and manufacturing given its global operations.",
#       "recommended_adjustments": "Maintain position in JNJ. Monitor for potential supply chain disruptions but overall risk is relatively low."
#     },
#     {
#       "symbol": "HD",
#       "company_name": "The Home Depot, Inc.",
#       "sector": "Consumer Discretionary",
#       "country_exposure": "United States, Canada, Mexico",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "As a home improvement retailer, Home Depot faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Home Depot likely has significant dependence on suppliers in China and other countries for its merchandise sourcing and supply chain.",
#       "recommended_adjustments": "Maintain position but closely monitor supply chain risks related to China sourcing. Consider reducing exposure if geopolitical tensions escalate."
#     },
#     {
#       "symbol": "ABBV",
#       "company_name": "AbbVie Inc.",
#       "sector": "Health Care",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As a biopharmaceutical company, AbbVie faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "AbbVie likely has some dependence on international suppliers for raw materials and manufacturing of pharmaceutical products.",
#       "recommended_adjustments": "Maintain position in ABBV. Monitor for potential supply chain disruptions but overall risk is relatively low."
#     },
#     {
#       "symbol": "PG",
#       "company_name": "The Procter & Gamble Company",
#       "sector": "Consumer Staples",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Moderate",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "Article 23 ter prohibiting misleading product review claims is relevant for P&G's consumer product brands. However, overall risk is moderate.",
#       "justify_dependance_risk": "P&G has a complex global supply chain and likely high dependence on suppliers worldwide for raw materials and manufacturing.",
#       "recommended_adjustments": "Maintain position but closely monitor for supply chain disruption risks given P&G's global sourcing footprint. Consider reducing exposure if geopolitical tensions escalate."
#     },
#     {
#       "symbol": "BAC",
#       "company_name": "Bank of America Corporation",
#       "sector": "Financials",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "As a financial services company, Bank of America faces low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Bank of America has a diversified global footprint with likely low supply chain dependence for its services business model.",
#       "recommended_adjustments": "Maintain position in BAC as both regulatory and dependence risks are low."
#     },
#     {
#       "symbol": "CVX",
#       "company_name": "Chevron Corporation",
#       "sector": "Energy",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "As an integrated oil and gas company, Chevron faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Chevron has significant global operations across the oil/gas value chain and likely high dependence on suppliers worldwide.",
#       "recommended_adjustments": "Maintain position but monitor for supply chain disruption risks given Chevron's complex global supply chain and operations."
#     },
#     {
#       "symbol": "KO",
#       "company_name": "The Coca-Cola Company",
#       "sector": "Consumer Staples",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Moderate",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "Article 23 ter prohibiting misleading product review claims is relevant for Coca-Cola's consumer brands. However, overall risk is moderate.",
#       "justify_dependance_risk": "Coca-Cola has a vast global bottling and distribution network with likely high dependence on suppliers worldwide.",
#       "recommended_adjustments": "Maintain position but closely monitor for supply chain risks across Coca-Cola's global footprint. Consider reducing exposure if geopolitical tensions escalate."
#     },
#     {
#       "symbol": "AMD",
#       "company_name": "Advanced Micro Devices, Inc.",
#       "sector": "Information Technology",
#       "country_exposure": "United States, China, Taiwan",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "As a semiconductor company, AMD faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "AMD likely has significant dependence on suppliers in Taiwan and China for semiconductor manufacturing and components.",
#       "recommended_adjustments": "Maintain position but monitor for supply chain risks, especially related to Taiwan/China tensions. Consider reducing exposure if geopolitical situation worsens."
#     },
#     {
#       "symbol": "GE",
#       "company_name": "General Electric Company",
#       "sector": "Industrials",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "As an industrial conglomerate, GE faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "GE has a vast global supply chain and manufacturing footprint with likely high supplier dependence worldwide, including in China.",
#       "recommended_adjustments": "Maintain position but closely monitor for supply chain disruption risks across GE's global operations. Consider reducing exposure if geopolitical tensions escalate."
#     },
#     {
#       "symbol": "TMUS",
#       "company_name": "T-Mobile US, Inc.",
#       "sector": "Communication Services",
#       "country_exposure": "United States, China, South Korea",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As a telecommunications provider, T-Mobile faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "T-Mobile likely has some dependence on network equipment suppliers from China and South Korea.",
#       "recommended_adjustments": "Maintain position in TMUS. Monitor for potential supply chain disruptions but overall risk is relatively low."
#     },
#     {
#       "symbol": "CSCO",
#       "company_name": "Cisco Systems, Inc.",
#       "sector": "Information Technology",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As a networking equipment provider, Cisco faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Cisco likely has some dependence on contract manufacturers and suppliers globally for its hardware products.",
#       "recommended_adjustments": "Maintain position in CSCO. Monitor for potential supply chain disruptions but overall risk is relatively low."
#     },
#     {
#       "symbol": "PM",
#       "company_name": "Philip Morris International Inc.",
#       "sector": "Consumer Staples",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Moderate",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "Article 23 ter prohibiting misleading product review claims is relevant for PMI's consumer brands. However, overall risk is moderate.",
#       "justify_dependance_risk": "PMI has a vast global supply chain and likely high dependence on suppliers worldwide for tobacco, raw materials and manufacturing.",
#       "recommended_adjustments": "Maintain position but closely monitor for supply chain disruption risks across PMI's global sourcing footprint. Consider reducing exposure if geopolitical tensions escalate."
#     },
#     {
#       "symbol": "WFC",
#       "company_name": "WELLS FARGO & COMPANY/MN Wells Fargo & Company",
#       "sector": "Financials",
#       "country_exposure": "United States",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "As a financial services company focused on the US market, Wells Fargo faces low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Wells Fargo's US-centric business model likely has low supply chain dependence.",
#       "recommended_adjustments": "Maintain position in WFC as both regulatory and dependence risks are low."
#     },
#     {
#       "symbol": "UNH",
#       "company_name": "UnitedHealth Group",
#       "sector": "Health Care",
#       "country_exposure": "United States, Some International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "As a managed healthcare company primarily focused on the US market, UnitedHealth faces low direct regulatory risk from the EU directives.",
#       "justify_dependance_risk": "UnitedHealth's services business model and US focus likely result in low supply chain dependence.",
#       "recommended_adjustments": "Maintain position in UNH as both regulatory and dependence risks are low."
#     },
#     {
#       "symbol": "MS",
#       "company_name": "Morgan Stanley",
#       "sector": "Financials",
#       "country_exposure": "Global",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "As a financial services company, Morgan Stanley faces low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Morgan Stanley's global services business model likely has low supply chain dependence.",
#       "recommended_adjustments": "Maintain position in MS as both regulatory and dependence risks are low."
#     },
#     {
#       "symbol": "GS",
#       "company_name": "The Goldman Sachs Group, Inc.",
#       "sector": "Financials",
#       "country_exposure": "Global",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "As a financial services company, Goldman Sachs faces low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Goldman's global services business model likely has low supply chain dependence.",
#       "recommended_adjustments": "Maintain position in GS as both regulatory and dependence risks are low."
#     },
#     {
#       "symbol": "LIN",
#       "company_name": "Linde plc",
#       "sector": "Materials",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As an industrial gas company, Linde faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Linde likely has some dependence on global suppliers for raw materials and manufacturing given its international operations.",
#       "recommended_adjustments": "Maintain position in LIN. Monitor for potential supply chain disruptions but overall risk is relatively low."
#     },
#     {
#       "symbol": "CRM",
#       "company_name": "Salesforce, Inc.",
#       "sector": "Information Technology",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As a cloud software provider, Salesforce faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Salesforce likely has some dependence on cloud infrastructure providers and hardware suppliers globally.",
#       "recommended_adjustments": "Maintain position in CRM. Monitor for potential supply chain disruptions but overall risk is relatively low."
#     },
#     {
#       "symbol": "ABT",
#       "company_name": "Abbott Laboratories",
#       "sector": "Health Care",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As a healthcare company, Abbott faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Abbott likely has some dependence on international suppliers for raw materials and manufacturing of medical products.",
#       "recommended_adjustments": "Maintain position in ABT. Monitor for potential supply chain disruptions but overall risk is relatively low."
#     },
#     {
#       "symbol": "IBM",
#       "company_name": "International Business Machines Corporation (IBM)",
#       "sector": "Information Technology",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As an enterprise IT company, IBM faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "IBM likely has some dependence on hardware suppliers and manufacturers globally for its products and services.",
#       "recommended_adjustments": "Maintain position in IBM. Monitor for potential supply chain disruptions but overall risk is relatively low."
#     },
#     {
#       "symbol": "MCD",
#       "company_name": "McDonald's Corporation",
#       "sector": "Consumer Discretionary",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Moderate",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "Article 23 ter prohibiting misleading product review claims is relevant for McDonald's food products and marketing. However, overall risk is moderate.",
#       "justify_dependance_risk": "McDonald's has a vast global supply chain for food and materials, likely with high dependence on suppliers worldwide.",
#       "recommended_adjustments": "Maintain position but closely monitor for supply chain disruption risks across McDonald's global sourcing footprint. Consider reducing exposure if geopolitical tensions escalate."
#     },
#     {
#       "symbol": "AXP",
#       "company_name": "American Express Company",
#       "sector": "Financials",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "As a financial services company, American Express faces low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "AmEx's services business model likely has low supply chain dependence.",
#       "recommended_adjustments": "Maintain position in AXP as both regulatory and dependence risks are low."
#     },
#     {
#       "symbol": "RTX",
#       "company_name": "RTX Corporation Raytheon Technologies Corporation",
#       "sector": "Industrials",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "As an aerospace and defense company, Raytheon faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Raytheon likely has significant dependence on suppliers globally for raw materials and manufacturing across its aerospace and defense products.",
#       "recommended_adjustments": "Maintain position but closely monitor for potential supply chain disruptions given Raytheon's global supplier footprint. Consider reducing exposure if geopolitical tensions escalate."
#     },
#     {
#       "symbol": "MRK",
#       "company_name": "Merck & Co., Inc.",
#       "sector": "Health Care",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As a pharmaceutical company, Merck faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Merck likely has some dependence on international suppliers for raw materials and manufacturing of pharmaceutical products.",
#       "recommended_adjustments": "Maintain position in MRK. Monitor for potential supply chain disruptions but overall risk is relatively low."
#     },
#     {
#       "symbol": "DIS",
#       "company_name": "The Walt Disney Company",
#       "sector": "Communication Services",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As a media and entertainment company, Disney faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Disney likely has some dependence on international suppliers for products, merchandise and services related to its parks, resorts and consumer products businesses.",
#       "recommended_adjustments": "Maintain position in DIS. Monitor for potential supply chain disruptions but overall risk is relatively low."
#     },
#     {
#       "symbol": "T",
#       "company_name": "AT&T Inc.",
#       "sector": "Communication Services",
#       "country_exposure": "United States, Mexico",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As a telecommunications provider focused on the US market, AT&T faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "AT&T likely has some dependence on network equipment suppliers globally, including from higher risk regions.",
#       "recommended_adjustments": "Maintain position in T. Monitor for potential supply chain disruptions but overall risk is relatively low."
#     },
#     {
#       "symbol": "PEP",
#       "company_name": "PepsiCo, Inc.",
#       "sector": "Consumer Staples",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Moderate",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "Article 23 ter prohibiting misleading product review claims is relevant for PepsiCo's consumer brands. However, overall risk is moderate.",
#       "justify_dependance_risk": "PepsiCo has a vast global supply chain and distribution network with likely high dependence on suppliers worldwide.",
#       "recommended_adjustments": "Maintain position but closely monitor for supply chain disruption risks across PepsiCo's global sourcing footprint. Consider reducing exposure if geopolitical tensions escalate."
#     },
#     {
#       "symbol": "INTU",
#       "company_name": "Intuit Inc.",
#       "sector": "Information Technology",
#       "country_exposure": "United States, Canada",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Low",
#       "justify_regulatory_risk": "As a financial software company, Intuit faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Intuit's software-focused business model likely has low supply chain dependence.",
#       "recommended_adjustments": "Maintain position in INTU as both regulatory and dependence risks are low."
#     },
#     {
#       "symbol": "CAT",
#       "company_name": "Caterpillar Inc.",
#       "sector": "Industrials",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "High",
#       "justify_regulatory_risk": "As a manufacturer of construction and mining equipment, Caterpillar faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Caterpillar has a vast global supply chain and manufacturing footprint with likely high dependence on suppliers worldwide, including higher risk regions.",
#       "recommended_adjustments": "Maintain position but closely monitor for supply chain disruption risks across Caterpillar's global operations. Consider reducing exposure if geopolitical tensions escalate."
#     },
#     {
#       "symbol": "UBER",
#       "company_name": "Uber Technologies, Inc.",
#       "sector": "Industrials",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Moderate",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "Article 23 ter prohibiting misleading product review claims could be relevant for Uber's ride-hailing and delivery services. However, overall risk is moderate.",
#       "justify_dependance_risk": "Uber likely has moderate dependence on suppliers globally for its operations across mobility, delivery and freight segments.",
#       "recommended_adjustments": "Maintain position in UBER but monitor for regulatory developments around consumer reviews as well as potential supply chain disruptions."
#     },
#     {
#       "symbol": "VZ",
#       "company_name": "Verizon Communications Inc.",
#       "sector": "Communication Services",
#       "country_exposure": "United States, International",
#       "regulatory_risk_score": "Low",
#       "dependance_risk_score": "Moderate",
#       "justify_regulatory_risk": "As a telecommunications provider, Verizon faces relatively low direct regulatory risk from the EU consumer directives.",
#       "justify_dependance_risk": "Verizon likely has some dependence on network equipment suppliers globally, including from higher risk regions.",
#       "recommended_adjustments": "Maintain position in VZ. Monitor for potential supply chain disruptions but overall risk is relatively low."
#     }
#   ]
# }

# %%
import os
import json
import pandas as pd
import unicodedata
import re

def robust_read_csv(path):
    # Essaye UTF-8 puis latin1 au cas où
    for enc in ["utf-8-sig", "utf-8", "latin1"]:
        try:
            return pd.read_csv(path, encoding=enc)
        except Exception:
            continue
    raise RuntimeError(f"Impossible de lire le CSV: {path}")

def normalize_text(s):
    """Normalise pour matching par nom: minuscule, sans accents, espaces simplifiés, sans ponctuation."""
    if pd.isna(s):
        return ""
    s = str(s).strip().lower()
    s = unicodedata.normalize("NFKD", s)
    s = "".join(ch for ch in s if not unicodedata.combining(ch))
    s = re.sub(r"[^\w\s]", " ", s)       # retire ponctuation
    s = re.sub(r"\s+", " ", s).strip()   # espaces multiples -> 1
    return s

def normalize_symbol(s):
    if pd.isna(s):
        return ""
    return str(s).strip().upper()

def find_first_col(columns, candidates):
    low = {c.lower(): c for c in columns}
    for cand in candidates:
        if cand.lower() in low:
            return low[cand.lower()]
    return None

def main(csv_path, json_path, output_path=None):
    if output_path is None:
        root, ext = os.path.splitext(csv_path)
        output_path = f"{root}_augmented{ext}"
        unmatched_report = f"{root}_unmatched_report.csv"
    else:
        root, ext = os.path.splitext(output_path)
        unmatched_report = f"{root}_unmatched_report.csv"

    # 1) Charger fichiers
    df_csv = robust_read_csv(csv_path)

    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    pa = data.get("portfolio_analysis", [])
    if not pa:
        raise ValueError("Le JSON ne contient pas de clé 'portfolio_analysis' non vide.")

    df_json = pd.DataFrame(pa)

    # 2) Préparer colonnes depuis JSON
    for col in ["regulatory_risk_score", "dependance_risk_score",
                "justify_regulatory_risk", "justify_dependance_risk",
                "recommended_adjustments", "symbol", "company_name"]:
        if col not in df_json.columns:
            df_json[col] = None

    df_json["reglementary_score"] = df_json["regulatory_risk_score"]
    df_json["dependance_score"] = df_json["dependance_risk_score"]
    df_json["recommandation"] = (
        df_json["justify_regulatory_risk"].fillna("").astype(str).str.strip() + " " +
        df_json["justify_dependance_risk"].fillna("").astype(str).str.strip() + " " +
        df_json["recommended_adjustments"].fillna("").astype(str).str.strip()
    ).str.replace(r"\s+", " ", regex=True).str.strip()

    # Garder uniquement les colonnes utiles côté JSON pour le merge
    df_json_small = df_json[[
        "symbol", "company_name", "reglementary_score", "dependance_score", "recommandation"
    ]].copy()

    # 3) Déterminer clé(s) de jointure
    symbol_col_csv = find_first_col(
        df_csv.columns,
        ["symbol", "ticker", "SYM", "SYMBOL", "Ticker"]
    )
    company_col_csv = find_first_col(
        df_csv.columns,
        ["company_name", "Company", "Company Name", "Name", "Issuer", "Entreprise", "Société"]
    )

    # Préparer versions normalisées
    df_json_small["_sym"] = df_json_small["symbol"].map(normalize_symbol)
    df_json_small["_name"] = df_json_small["company_name"].map(normalize_text)

    # Supprimer doublons côté JSON (priorité symbole, sinon nom)
    df_json_dedup_sym = df_json_small.copy()
    df_json_dedup_sym = df_json_dedup_sym.sort_values(by=["_sym", "_name"]).drop_duplicates(subset=["_sym"], keep="first")
    df_json_dedup_name = df_json_small.copy()
    df_json_dedup_name = df_json_dedup_name.sort_values(by=["_name", "_sym"]).drop_duplicates(subset=["_name"], keep="first")

    df_enriched = df_csv.copy()
    df_enriched["_match_key"] = None
    unmatched_rows = None

    merged = False

    # 4) Essayer le merge par symbole
    if symbol_col_csv is not None and df_json_dedup_sym["_sym"].str.len().gt(0).any():
        df_enriched["_sym"] = df_enriched[symbol_col_csv].map(normalize_symbol)

        df_enriched = df_enriched.merge(
            df_json_dedup_sym[
                ["_sym", "reglementary_score", "dependance_score", "recommandation"]
            ],
            on="_sym",
            how="left",
            suffixes=("", "")
        )
        df_enriched["_match_key"] = df_enriched["_match_key"].fillna("symbol")

        # Capturer non appariés après symbole (si on a un nom pour 2ème tentative)
        if company_col_csv is not None:
            still_unmatched_mask = df_enriched["reglementary_score"].isna() & df_enriched["dependance_score"].isna() & df_enriched["recommandation"].isna()
            if still_unmatched_mask.any():
                df_enriched.loc[still_unmatched_mask, "_name"] = df_enriched.loc[still_unmatched_mask, company_col_csv].map(normalize_text)

                # 5) Essayer un 2ème passage par nom
                df_enriched = df_enriched.merge(
                    df_json_dedup_name[
                        ["_name", "reglementary_score", "dependance_score", "recommandation"]
                    ],
                    on="_name",
                    how="left",
                    suffixes=("", "_by_name")
                )

                # Remplir uniquement là où c'est encore NaN
                for col in ["reglementary_score", "dependance_score", "recommandation"]:
                    df_enriched[col] = df_enriched[col].where(~df_enriched[col].isna(), df_enriched[f"{col}_by_name"])
                    if f"{col}_by_name" in df_enriched.columns:
                        df_enriched.drop(columns=[f"{col}_by_name"], inplace=True)

                df_enriched["_match_key"] = df_enriched["_match_key"].mask(
                    df_enriched["_match_key"].eq("symbol") & (
                        df_enriched["reglementary_score"].notna() |
                        df_enriched["dependance_score"].notna() |
                        df_enriched["recommandation"].notna()
                    ),
                    "symbol"
                )
                df_enriched["_match_key"] = df_enriched["_match_key"].fillna("name")

        merged = True

    # 6) Si pas de symbole exploitable, tenter directement par nom
    if not merged and company_col_csv is not None:
        df_enriched["_name"] = df_enriched[company_col_csv].map(normalize_text)
        df_enriched = df_enriched.merge(
            df_json_dedup_name[
                ["_name", "reglementary_score", "dependance_score", "recommandation"]
            ],
            on="_name",
            how="left"
        )
        df_enriched["_match_key"] = "name"
        merged = True

    if not merged:
        raise ValueError(
            "Impossible de trouver une clé de jointure. "
            "Aucune colonne 'symbol/ticker' ni 'company_name/Company/Name' détectée dans le CSV."
        )

    # 7) Rapporter les non appariés
    unmatched_mask = df_enriched["reglementary_score"].isna() & df_enriched["dependance_score"].isna() & df_enriched["recommandation"].isna()
    if unmatched_mask.any():
        unmatched_rows = df_enriched[unmatched_mask].copy()
        # Garder seulement colonnes utiles dans le rapport
        keep_cols = [c for c in [symbol_col_csv, company_col_csv] if c is not None]
        keep_cols += ["_sym", "_name", "_match_key"]
        keep_cols = [c for c in keep_cols if c in unmatched_rows.columns]
        unmatched_rows = unmatched_rows[keep_cols].drop_duplicates()
        unmatched_rows.to_csv(unmatched_report, index=False, encoding="utf-8-sig")
        print(f"⚠️ Lignes sans correspondance: {len(unmatched_rows)} — rapport: {unmatched_report}")

    # 8) Nettoyage colonnes techniques
    for tmp in ["_sym", "_name"]:
        if tmp in df_enriched.columns:
            df_enriched.drop(columns=[tmp], inplace=True)

    # 9) Sauvegarde
    df_enriched.to_csv(output_path, index=False, encoding="utf-8-sig")
    print(f"✅ Fichier enrichi écrit dans: {output_path}")
    print("Colonnes ajoutées: reglementary_score, dependance_score, recommandation")

# --- Paramètres à adapter / ou exécuter tels quels si chemins valides ---
csv_path = "/home/sagemaker-user/shared/streamlit-app/data/analysis_result/4/4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL.csv"
json_path = "/home/sagemaker-user/shared/law_on_companies/summary/4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL.json"
main(csv_path, json_path)
# Out:
# ⚠️ Lignes sans correspondance: 40 — rapport: /home/sagemaker-user/shared/streamlit-app/data/analysis_result/4/4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL_unmatched_report.csv
# ✅ Fichier enrichi écrit dans: /home/sagemaker-user/shared/streamlit-app/data/analysis_result/4/4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL_augmented.csv
# Colonnes ajoutées: reglementary_score, dependance_score, recommandation
